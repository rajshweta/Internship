# %%
#import libraries
import selenium
from selenium import webdriver
import pandas as pd

#Importing requests
import requests

# importing regex
import re

import warnings
warnings.filterwarnings('ignore')

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# 1) Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank B) Name C) Artist D) Upload date E) Views

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')
time.sleep(1)

#initializing blank lists
name=[]
rank=[]
artist=[]
views=[]
upload_date=[]

# scraping names of the video
try:
    names=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
    for i in names:
        name.append(i.text)
except NoSuchElementException: # handling no such element exception
    name.append('-')    
time.sleep(1)   

#scraping rank of the video
try:
    ranks=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
    for i in ranks:
        rank.append(i.text)
except NoSuchElementException: # handling no such element exception
    rank.append('-')
time.sleep(1)

#scraping Artist of the video
try:
    artists=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
    for i in artists:
        artist.append(i.text)
except NoSuchElementException:  # handling no such element exception
    artist.append('-')
time.sleep(1)  

#scraping views of the video
try:
    views_list=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
    for i in views_list:
        views.append(i.text)
except NoSuchElementException: # handling no such element exception
    views.append('-')   
time.sleep(1) 

#scraping upload_date of the video
try:
    upload_date_list=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
    for i in upload_date_list:
        upload_date.append(i.text)
except NoSuchElementException: # handling no such element exception
    upload_date.append('-')
time.sleep(1) 

df = pd.DataFrame({'Name':name,'Rank':rank,'Artist':artist,'Views':views,'Upload Date':upload_date})
df
# Out:
#                                                Name Rank  \
# 0                             "Baby Shark Dance"[4]   1.
# 1                                    "Despacito"[7]   2.
# 2                        "Johny Johny Yes Papa"[14]   3.
# 3                                "Shape of You"[15]   4.
# 4                                   "Bath Song"[17]   5.
# 5                               "See You Again"[18]   6.
# 6                 "Phonics Song with Two Words"[23]   7.
# 7                                 "Uptown Funk"[24]   8.
# 8   "Learning Colors – Colorful Eggs on a Farm"[25]   9.
# 9                               "Gangnam Style"[26]  10.
# 10                          "Wheels on the Bus"[31]  11.
# 11   "Masha and the Bear – Recipe for Disaster"[32]  12.
# 12                             "Dame Tu Cosita"[33]  13.
# 13                                      "Sugar"[34]  14.
# 14                                       "Roar"[35]  15.
# 15                             "Counting Stars"[36]  16.
# 16                                      "Sorry"[37]  17.
# 17                                     "Axel F"[38]  18.
# 18                          "Thinking Out Loud"[39]  18.
# 19                        "Baa Baa Black Sheep"[40]  20.
# 20                                 "Dark Horse"[41]  21.
# 21                                      "Faded"[42]  22.
# 22                             "Girls Like You"[43]  23.
# 23                                 "Let Her Go"[44]  24.
# 24                                   "Bailando"[45]  25.
# 25                                    "Perfect"[46]  26.
# 26                                    "Lean On"[47]  27.
# 27           "Waka Waka (This Time for Africa)"[48]  28.
# 28                               "Shake It Off"[49]  29.
# 29          "Humpty the train on a fruits ride"[50]  30.
#
#                                            Artist  Views        Upload Date
# 0     Pinkfong Baby Shark - Kids' Songs & Stories  11.64      June 17, 2016
# 1                                      Luis Fonsi   8.00   January 12, 2017
# 2                                     LooLoo Kids   6.51    October 8, 2016
# 3                                      Ed Sheeran   5.84   January 30, 2017
# 4                      Cocomelon – Nursery Rhymes   5.69        May 2, 2018
# 5                                     Wiz Khalifa   5.68      April 6, 2015
# 6                                       ChuChu TV   4.98      March 6, 2014
# 7                                     Mark Ronson   4.74  November 19, 2014
# 8                                     Miroshka TV   4.70  February 27, 2018
# 9                                             Psy   4.59      July 15, 2012
# 10                     Cocomelon – Nursery Rhymes   4.53       May 24, 2018
# 11                                     Get Movies   4.51   January 31, 2012
# 12                                      El Chombo   4.12      April 5, 2018
# 13                                       Maroon 5   3.78   January 14, 2015
# 14                                     Katy Perry   3.68  September 5, 2013
# 15                                    OneRepublic   3.67       May 31, 2013
# 16                                  Justin Bieber   3.60   October 22, 2015
# 17                                     Crazy Frog   3.57      June 16, 2009
# 18                                     Ed Sheeran   3.51    October 7, 2014
# 19                     Cocomelon – Nursery Rhymes   3.41      June 25, 2018
# 20                                     Katy Perry   3.38  February 20, 2014
# 21                                    Alan Walker   3.36   December 3, 2015
# 22                                       Maroon 5   3.34       May 31, 2018
# 23                                      Passenger   3.33      July 25, 2012
# 24                               Enrique Iglesias   3.29     April 11, 2014
# 25                                     Ed Sheeran   3.29   November 9, 2017
# 26                                    Major Lazer   3.28     March 22, 2015
# 27                                        Shakira   3.28       June 4, 2010
# 28                                   Taylor Swift   3.22    August 18, 2014
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   3.20   January 26, 2018

# %% [markdown]
# 2) Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI) B) Series C) Place D) Date E) Time

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://www.bcci.tv/')
time.sleep(1)

#Opening International fixtures page
fixtures=driver.find_element(By.XPATH,"/html/body/div[5]/div/div[2]/div/div[2]/div/div[1]/div[2]/a") 
driver.execute_script("arguments[0].click();", fixtures)
time.sleep(1)

#initializing empty list
Match_title = []
Series = []
Place = []
Date = []
Time = []

title=driver.find_elements(By.XPATH,"//div[@class='fix-place ng-binding ng-scope']/span[@class='matchOrderText ng-binding ng-scope']") #Title of the Seriers
for i in title:
    Series.append(i.text)
    
print(len(Series))

    
name=driver.find_elements(By.XPATH,"//h5[@class='fix-text']/span[@class='ng-binding']") #Match Title
for i in name:
    Match_title.append(i.text)
print(len(Match_title))
    
loc=driver.find_elements(By.XPATH,"//div[@class='fix-place ng-binding ng-scope']") #Location
for i in loc:
    Place.append(i.text)
print(len(Place))
    
dt=driver.find_elements(By.XPATH,"//div[@class='match-card-left match-schedule']/h5") #Day
for i in dt:
    Date.append(i.text) #adding Day and Month to form Date
print(len(Date))
    
tim=driver.find_elements(By.XPATH,"//div[@class='match-card-right match-schedule ']/h5") #Time
for i in tim:
    Time.append(i.text)
print(len(Time))
    
df = pd.DataFrame({'Title':Match_title,'Series':Series,'Place':Place,'Date':Date,'Time':Time})
df
# Out:
# 8
# 8
# 8
# 8
# 8
#                                           Title      Series  \
# 0  INDIA TOUR OF NEW ZEALAND T20 SERIES 2022-23  1st T20I -
# 1  INDIA TOUR OF NEW ZEALAND T20 SERIES 2022-23  2nd T20I -
# 2  INDIA TOUR OF NEW ZEALAND T20 SERIES 2022-23  3rd T20I -
# 3  INDIA TOUR OF NEW ZEALAND ODI SERIES 2022-23   1st ODI -
# 4  INDIA TOUR OF NEW ZEALAND ODI SERIES 2022-23   2nd ODI -
# 5  INDIA TOUR OF NEW ZEALAND ODI SERIES 2022-23   3rd ODI -
# 6   INDIA TOUR OF BANGLADESH ODI SERIES 2022-23   1st ODI -
# 7   INDIA TOUR OF BANGLADESH ODI SERIES 2022-23   2nd ODI -
#
#                                                Place         Date  \
# 0                 1st T20I - Sky Stadium, Wellington  18 NOV 2022
# 1               2nd T20I - Bay Oval, Mount Maunganui  20 NOV 2022
# 2                     3rd T20I - Mclean Park, Napier  22 NOV 2022
# 3                      1st ODI - Eden Park, Auckland  25 NOV 2022
# 4                    2nd ODI - Seddon Park, Hamilton  27 NOV 2022
# 5                3rd ODI - Hagley Oval, Christchurch  30 NOV 2022
# 6  1st ODI - Shere Bangla National Stadium, Mirpu...   4 DEC 2022
# 7  2nd ODI - Shere Bangla National Stadium, Mirpu...   7 DEC 2022
#
#            Time
# 0  12:00 PM IST
# 1  12:00 PM IST
# 2  12:00 PM IST
# 3   7:00 AM IST
# 4   7:00 AM IST
# 5   7:00 AM IST
# 6  12:30 PM IST
# 7  12:30 PM IST

# %% [markdown]
# 3) Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# You need to find following details:
# A) Name B) Description

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://www.guru99.com/')
time.sleep(1)

#clicking on selenium option under testing menu open its tutorial
selenium_link=driver.find_element(By.XPATH,"//a[@title='Selenium']")
try:
    selenium_link.click()
except:          #handling element not clickable exception
    driver.get(selenium_link.get_attribute('href'))
time.sleep(1)

#clicking on Selenium Exception Handling (Common Exceptions List) under Advance Webdriver Stuff!
exception_handle_link=driver.find_element(By.XPATH,"//a[@title='Selenium Exception Handling (Common Exceptions List)']")
try:
    driver.execute_script("arguments[0].click();", exception_handle_link)
except ElementNotInteractableException:      #handling element not clickable exception
    driver.get(exception_handle_link.get_attribute('href'))              
time.sleep(1)    

#scraping exceptions names
name=[]
desc=[]
try:
    names=driver.find_elements(By.XPATH,"//div[@class='entry-content single-content']/p")
    for i in names[0:40]:
        name.append(i.text.split(':')[0])
        desc.append(i.text.split(':')[1])
except NoSuchElementException:               #handling no such element exception
    name.append('-')
    desc.append('-')
time.sleep(1)   

#creating dataframe
df=pd.DataFrame({"Exception_name":name,"Description":desc})
df
# Out:
#                              Exception_name  \
# 0             1. ElementNotVisibleException
# 1          2. ElementNotSelectableException
# 2                 3. NoSuchElementException
# 3                   4. NoSuchFrameException
# 4                5. NoAlertPresentException
# 5                  6. NoSuchWindowException
# 6         7. StaleElementReferenceException
# 7               8. SessionNotFoundException
# 8                       9. TimeoutException
# 9                    10. WebDriverException
# 10            11. ConnectionClosedException
# 11     12. ElementClickInterceptedException
# 12      13. ElementNotInteractableException
# 13             14. ErrorInResponseException
# 14  15. ErrorHandler.UnknownServerException
# 15         16. ImeActivationFailedException
# 16             17. ImeNotAvailableException
# 17         18. InsecureCertificateException
# 18             19. InvalidArgumentException
# 19         20. InvalidCookieDomainException
# 20          21. InvalidCoordinatesException
# 21         22. InvalidElementStateException
# 22            23. InvalidSessionIdException
# 23       24. InvalidSwitchToTargetException
# 24                  25. JavascriptException
# 25                        26. JsonException
# 26             27. NoSuchAttributeException
# 27       28. MoveTargetOutOfBoundsException
# 28               29. NoSuchContextException
# 29                30. NoSuchCookieException
# 30                    31. NotFoundException
# 31          32. RemoteDriverServerException
# 32                  33. ScreenshotException
# 33           34. SessionNotCreatedException
# 34           35. UnableToSetCookieException
# 35           36. UnexpectedTagNameException
# 36              37. UnhandledAlertException
# 37      38. UnexpectedAlertPresentException
# 38               39. UnknownMethodException
# 39          40. UnreachableBrowserException
#
#                                           Description
# 0    This type of Selenium exception occurs when a...
# 1    This Selenium exception occurs when an elemen...
# 2    This Exception occurs if an element could not...
# 3    This Exception occurs if the frame target to ...
# 4    This Exception occurs when you switch to no p...
# 5    This Exception occurs if the window target to...
# 6    This Selenium exception occurs happens when t...
# 7    The WebDriver is acting after you quit the br...
# 8    Thrown when there is not enough time for a co...
# 9    This Exception takes place when the WebDriver...
# 10   This type of Exception takes place when there...
# 11   The command may not be completed as the eleme...
# 12   This Selenium exception is thrown when any el...
# 13   This happens while interacting with the Firef...
# 14   Exception is used as a placeholder in case if...
# 15   This expectation will occur when IME engine a...
# 16    It takes place when IME support is unavailable.
# 17   Navigation made the user agent to hit a certi...
# 18   It occurs when an argument does not belong to...
# 19   This happens when you try to add a cookie und...
# 20   This type of Exception matches an interacting...
# 21   It occurs when command can’t be finished when...
# 22   This Exception took place when the given sess...
# 23   This occurs when the frame or window target t...
# 24   This issue occurs while executing JavaScript ...
# 25   It occurs when you afford to get the session ...
# 26   This kind of Exception occurs when the attrib...
# 27   It takes place if the target provided to the ...
# 28           ContextAware does mobile device testing.
# 29   This Exception occurs when no cookie matching...
# 30   This Exception is a subclass of WebDriverExce...
# 31   This Selenium exception is thrown when the se...
# 32            It is not possible to capture a screen.
# 33   It happens when a new session could not be su...
# 34   This occurs if a driver is unable to set a co...
# 35   Happens if a support class did not get a web ...
# 36   This expectation occurs when there is an aler...
# 37   It occurs when there is the appearance of an ...
# 38   This Exception happens when the requested com...
# 39   This Exception occurs only when the browser i...

# %% [markdown]
# 4) Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank B) State C) GSDP(18-19) D) GSDP(17-18) E) Share(2017) F) GDP($ billion)

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://www.statisticstimes.com/economy/india-statistics.php')
time.sleep(1)

# Clicking on GDP of Indian Economy
GDP = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# Creating empty list
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# Scraping Rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# Scraping State
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    
# Scraping GSDP at current price (19-20)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    # Scraping GSDP at current price (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]"):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    
# Scraping Share (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    
# Scraping GDP $ billion
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]"):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
# Creating DataFrame from the scraped data
df = pd.DataFrame({'Rank':Rank,'State':State,'GSDP at current price (19-20)':GSDP1,'GSDP at current price (18-19)':GSDP2,'Share(18-19)':Share,' GDP($ billion)':GDP_billion})
df
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share(18-19)  GDP($ billion)
# 0                      2,632,792       13.94%         399.921
# 1                      1,630,208        8.63%         247.629
# 2                      1,584,764        8.39%         240.726
# 3                      1,502,899        7.96%         228.290
# 4                      1,493,127        7.91%         226.806
# ..                           ...          ...             ...
# 61                        25,141        0.15%          17,060
# 62                        24,534        0.15%               -
# 63                        22,488        0.13%               -
# 64                        20,947        0.13%          17,797
# 65                             -            -               -
#
# [66 rows x 6 columns]

# %% [markdown]
# 5) Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://github.com/')
time.sleep(1)

# Getting open source button and clicking on it
explore = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/button").click()

#Selecting trending option
trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/ul[3]/li[3]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

#Creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

#Fetching urls for each repository
repository = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))

    
# Scraping Repository Title data
title = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)

    
# Scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(1)
       
    # Scraping Repository Description data
    try:
        desc = driver.find_element(By.XPATH,'//p[@class="f4 my-3"]')
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
        # Scraping Contributors Count data
    try:
        contributor = driver.find_element(By.XPATH,"//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
         
    # Scraping Languages used data
    try:
        for i in driver.find_elements(By.XPATH,"//span[@class='color-fg-default text-bold mr-1']"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
#creating dataframe
Github=pd.DataFrame({})
Github['Repository title'] = repository_title
Github['Repository description'] = Description
Github['Contributors count'] = Contributors
Github['Language used'] = Language
Github
# Out:
#                             Repository title  \
# 0               ilovexjp / health-code-index
# 1                  projectdiscovery / katana
# 2                       binwiederhier / ntfy
# 3      The-Run-Philosophy-Organization / run
# 4                     hpcaitech / ColossalAI
# 5                      solidjs / solid-start
# 6                              dotnet / maui
# 7                  AdguardTeam / AdGuardHome
# 8                              mli / autocut
# 9                               rome / tools
# 10                          doitsujin / dxvk
# 11                 PaddlePaddle / FastDeploy
# 12  infosecB / awesome-detection-engineering
# 13                   mouredev / Hello-Python
# 14              Azure / azure-sdk-for-python
# 15                karpathy / nn-zero-to-hero
# 16                         Ryujinx / Ryujinx
# 17                          Kaiser-DMr / -3D
# 18                 Azure / azure-sdk-for-net
# 19                    vinta / awesome-python
# 20          Asabeneh / 30-Days-Of-JavaScript
# 21        codecrafters-io / build-your-own-x
# 22                         TanStack / router
# 23                MicrosoftDocs / azure-docs
# 24                    jeecgboot / jeecg-boot
#
#                                Repository description Contributors count  \
# 0                                          健康码模拟 - 索引                  -
# 1   A next-generation crawling and spidering frame...                 10
# 2   Send push notifications to your phone or deskt...                 66
# 3   润学全球官方指定GITHUB，整理润学宗旨、纲领、理论和各类润之实例；解决为什么润，润去哪里...                 75
# 4   Colossal-AI: A Unified Deep Learning System fo...                 78
# 5                 SolidStart, the Solid app framework                 61
# 6   .NET MAUI is the .NET Multi-platform App UI, a...                467
# 7     Network-wide ads & trackers blocking DNS server                 79
# 8                                           用文本编辑器剪视频                  5
# 9   Unified developer tools for JavaScript, TypeSc...                184
# 10  Vulkan-based implementation of D3D9, D3D10 and...                115
# 11  ⚡️An Easy-to-use and Fast Deep Learning Model ...                 27
# 12  A list of useful Detection Engineering-related...                  -
# 13                                  Python desde cero                  -
# 14  This repository is for active development of t...                665
# 15                      Neural Networks: Zero to Hero                  2
# 16  Experimental Nintendo Switch Emulator written ...                128
# 17                                           李洵爱心跳动代码                  -
# 18  This repository is for active development of t...              1,284
# 19  A curated list of awesome Python frameworks, l...                395
# 20  30 days of JavaScript programming challenge is...                 33
# 21  Master programming by recreating your favorite...                 83
# 22  🤖 Type-safe router w/ built-in caching & URL s...                 65
# 23       Open source documentation of Microsoft Azure             5,000+
# 24  ⭐️「企业级低代码平台」前后端分离架构SpringBoot 2.x，SpringCloud，...                 11
#
#                                         Language used
# 0   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 1   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 2   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 3   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 4   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 5   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 6   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 7   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 8   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 9   [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 10  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 11  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 12  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 13  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 14  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 15  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 16  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 17  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 18  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 19  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 20  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 21  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 22  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 23  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...
# 24  [HTML, Go, Dockerfile, Go, JavaScript, Makefil...

# %% [markdown]
# 6) Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https:/www.billboard.com/')
time.sleep(1)

#clicking the hot 100 songs link
charts=driver.find_element(By.XPATH,"/html/body/div[3]/header/div/div[3]/div/nav/ul/li[1]/a")
try:
    charts.click()
except ElementNotInteractableException:
    driver.get(charts.get_attribute('href'))
time.sleep(2)

#scraping song names
song_name=[]
try:
    names=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[1]/h3")
    for i in names[1:]:
        song_name.append(i.text)
except NoSuchElementException:       #handling no such element exception
    song_name.append('-')
time.sleep(2)  
print(len(song_name))


#scraping artist_names 
artist_name=[]
try:
    names=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[1]/span")
    for i in names[1:]:
        artist_name.append(i.text)
except NoSuchElementException:        #handling no such element exception
    artist_name.append('-')
time.sleep(2)
print(len(artist_name))    

#scraping last week rank
last_week_rank=[]
try:
    ranks=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[4]/span")
    for i in ranks[1:]:
        last_week_rank.append(i.text)
except NoSuchElementException:        #handling no such element exception
    last_week_rank.append('-') 
time.sleep(2)
print(len(last_week_rank)) 

#scraping peak rank
peak_rank=[]
try:
    ranks=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[5]/span")
    for i in ranks[1:]:
        peak_rank.append(i.text)
except NoSuchElementException:      #handling no such element exception
    peak_rank.append('-')
time.sleep(2)
print(len(peak_rank))

#scraping weeks on chart
weeks=[]
try:
    week_count=driver.find_elements(By.XPATH,"//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']/li[6]/span")
    for i in week_count[1:]:
        weeks.append(i.text)
except NoSuchElementException:          #handling no such element exception
    weeks.append('-')
time.sleep(2)
print(len(weeks))


#creating dataframe
df=pd.DataFrame({'Song_Name':song_name,'Artist_Name':artist_name,'Last_week_rank':last_week_rank,'Peak':peak_rank,'Weeks_on_chart':weeks})
df
# Out:
# 99
# 99
# 99
# 99
# 99
#                        Song_Name             Artist_Name Last_week_rank Peak  \
# 0                     Lift Me Up                 Rihanna              -    2
# 1                         Unholy  Sam Smith & Kim Petras             11    1
# 2                      Bad Habit              Steve Lacy             12    1
# 3                      As It Was            Harry Styles             16    1
# 4                  Lavender Haze            Taylor Swift              2    2
# ..                           ...                     ...            ...  ...
# 94                  300 Blackout             Kodak Black              -   96
# 95                   Dear Reader            Taylor Swift             45   45
# 96                    Country On              Luke Bryan             92   72
# 97  Bzrp Music Sessions, Vol. 52      Bizarrap & Quevedo              -   79
# 98                     Evergreen             Omar Apollo             88   51
#
#    Weeks_on_chart
# 0               1
# 1               6
# 2              18
# 3              31
# 4               2
# ..            ...
# 94              1
# 95              2
# 96             11
# 97             10
# 98              7
#
# [99 rows x 5 columns]

# %% [markdown]
# 7) Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
#
# #was not able to track Recuiters page on this site, hence searching for top 10 data science jobs instead

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://www.naukri.com/')
time.sleep(1)

#was not able to track recruiters page so searching for Data Science Jobs instead

#entering designation and location as per the question
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Science')
time.sleep(1)

#click the search button
search = driver.find_element(By.XPATH,'/html/body/div[1]/div[6]/div/div/div[6]')
search.click()
time.sleep(1)

#initializing empty lists 
job_title = []
job_location = []
company_name = []
exp_required = []

#scraping job_title from given page
title = driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title[0:10]:
    job_title.append(i.text.strip())
    
#scraping job location
loc = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in loc[0:10]:
    job_location.append(i.text.strip())
    
#scraping company name
company = driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company[0:10]:
    company_name.append(i.text.strip())
    
#print(company_name)
#scraping experience
exp = driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]')
for i in exp[0:10]:
    exp_required.append(i.text.strip())
    
#creating a data frame
df = pd.DataFrame({"Job Title":job_title,"Location":job_location,"Company Name":company_name,"Experience Req":exp_required})
df
# Out:
#                                            Job Title  \
# 0                               Data Science Analyst
# 1                        Data Analyst - Data Science
# 2  Software Trainees in Data Science, Data Analyt...
# 3                              Analyst, Data Science
# 4            Data Science- supply chain optimization
# 5                   Principal Analyst - Data Science
# 6                             Analyst - Data Science
# 7              Data Science /Senior Business Analyst
# 8                               Manager Data Science
# 9                        Senior Analyst-Data Science
#
#                                          Location  \
# 0  Hybrid - Gurgaon/Gurugram, Bangalore/Bengaluru
# 1                Navi Mumbai, Bangalore/Bengaluru
# 2                 Bangalore/Bengaluru(Whitefield)
# 3                             Bangalore/Bengaluru
# 4  Hybrid - Gurgaon/Gurugram, Bangalore/Bengaluru
# 5              Pune, Chennai, Bangalore/Bengaluru
# 6                                          Mumbai
# 7                             Bangalore/Bengaluru
# 8                                          Remote
# 9                                Gurgaon/Gurugram
#
#                             Company Name Experience Req
# 0  EY Global Delivery Services India Llp       8-12 Yrs
# 1                         Sagality India        3-5 Yrs
# 2             MagicBase Royal BD Pvt Ltd        0-1 Yrs
# 3                      Johnson & Johnson        2-4 Yrs
# 4  EY Global Delivery Services India Llp       8-12 Yrs
# 5                           Gcc Services        2-5 Yrs
# 6                               Mondelez        1-4 Yrs
# 7                           Gcc Services        2-7 Yrs
# 8                               Mondelez        3-7 Yrs
# 9                              Accenture        5-8 Yrs

# %% [markdown]
# 8) Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get(' https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey- compare/')
time.sleep(1)

#not able to track the mentioned page

# %% [markdown]
# 9) Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://www.imdb.com/list/ls095964455/')
time.sleep(1)

# Creating empty lists
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# Scraping name of the movie
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

# Scrpaing Year span 
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-index unbold text-primary']"):
    Year_span.append(i.text)
    
# Scrpaing Genre 
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
# Scrpaing Run_time 
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
# Scrpaing Ratings 
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']/span[2]"):
    Ratings.append(i.text)
    
# Scrpaing Votes 
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)
    

df = pd.DataFrame({'Name':Name,'Year_span':Year_span,'Genre':Genre,'Run_time':Run_time,'Ratings':Ratings,'Votes':Votes})
df
# Out:
#                               Name Year_span                     Genre  \
# 0                  Game of Thrones        1.  Action, Adventure, Drama
# 1                  Stranger Things        2.    Drama, Fantasy, Horror
# 2                 The Walking Dead        3.   Drama, Horror, Thriller
# 3                   13 Reasons Why        4.  Drama, Mystery, Thriller
# 4                          The 100        5.    Drama, Mystery, Sci-Fi
# ..                             ...       ...                       ...
# 95                           Reign       96.                     Drama
# 96  A Series of Unfortunate Events       97.  Adventure, Comedy, Drama
# 97                  Criminal Minds       98.     Crime, Drama, Mystery
# 98           Scream: The TV Series       99.      Comedy, Crime, Drama
# 99      The Haunting of Hill House      100.    Drama, Horror, Mystery
#
#    Run_time Ratings      Votes
# 0    57 min     9.2  2,080,600
# 1    51 min     8.7  1,170,645
# 2    44 min     8.1    980,577
# 3    60 min     7.5    291,789
# 4    43 min     7.6    250,788
# ..      ...     ...        ...
# 95   42 min     7.4     50,006
# 96   50 min     7.8     61,150
# 97   42 min     8.1    196,791
# 98   45 min     7.1     41,469
# 99  572 min     8.6    243,391
#
# [100 rows x 6 columns]

# %% [markdown]
# 10) Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year

# %%
#connect to the driver
driver = webdriver.Chrome(r'F:\Project Data\flip robo\chromedriver.exe')

#opening the page on automated chrome browser
driver.get('https://archive.ics.uci.edu/')
time.sleep(1)

#Clicking on view all datasets link
datasets=driver.find_element(By.XPATH,"/html/body/table[1]/tbody/tr/td[2]/span[2]/a/font/b")
try:
    datasets.click()
except ElementNotInteractableException:
    driver.get(datasets.get_attribute('href'))

#Creating empty lists for storing the data
Name=[]
Type=[]
Task=[]
Attribute=[]
No_of_Instance=[]
No_of_Attribute=[]
Year=[]

#Scrapping the data having dataset name
try:
    names=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
    
#Scrapping the data having data type
try:
    types=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in types[1:]:
        Type.append(i.text)
except NoSuchElementException:
    Type.append('-')
    
#Scrapping the data having default task
try:
    task=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in task[1:]:
        Task.append(i.text)
except NoSuchElementException:
    Task.append('-')
        
#Scrapping the data having attribute types
try:
    attribute=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in attribute[1:]:
        Attribute.append(i.text)
except NoSuchElementException:
     Attribute.append('-')
        
#Scrapping the data having no of instances
try:
    instance=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in instance[1:]:
        No_of_Instance.append(i.text)
except NoSuchElementException:
    No_of_Instance.append('-')
        
#Scrapping the data having no of attributes
try:
    attribute_no=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in attribute_no[1:]:
        No_of_Attribute.append(i.text)
except NoSuchElementException:
    No_of_Attribute.append('-')
        
#Scrapping the data having the year details
try:
    year=driver.find_elements(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in year[1:]:
        Year.append(i.text)
except NoSuchElementException:
    Year.append('-')
    

#Creating the dataframe
df=pd.DataFrame({"Name":Name,"Data types":Type,"Default Task":Task,"Attribute types":Attribute, 
                 "No of instances":No_of_Instance,"No of atrributes":No_of_Attribute,"Year":Year})
df
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                      Data types          Default Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# 4                 Multivariate        Classification
# ..                          ...                   ...
# 617               Multivariate        Classification
# 618               Multivariate        Classification
# 619                                   Classification
# 620  Multivariate, Time-Series        Classification
# 621                 Univariate            Regression
#
#                  Attribute types No of instances No of atrributes   Year
# 0    Categorical, Integer, Real            4177                8   1995
# 1          Categorical, Integer           48842               14   1996
# 2    Categorical, Integer, Real             798               38
# 3                   Categorical           37711              294   1998
# 4    Categorical, Integer, Real             452              279   1998
# ..                           ...             ...              ...    ...
# 617               Integer, Real           75840              525   2020
# 618               Integer, Real             400               50   2020
# 619                                        1014                7   2020
# 620                        Real           10129               16   2021
# 621                        Real            4000                2   2021
#
# [622 rows x 7 columns]
